# %% [markdown]
# ## Handling missing Values using sklearn

# %%
# !pip install -q icecream
# To print variable name along with the contents
from icecream import ic

# Configure the output to include variable names
ic.configureOutput(prefix='', includeContext=False)

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('/content/supermarket_sales_frac_missing_val.csv').drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#      Invoice ID Branch       City Customer type  Gender        Product line  \
# 0   451-28-5717      C  Naypyitaw           NaN     NaN                 NaN
# 1   137-63-5492      C  Naypyitaw           NaN    Male                 NaN
# 2   733-29-1227      C  Naypyitaw        Normal    Male  Home and lifestyle
# 3   322-02-2271      B   Mandalay           NaN  Female   Sports and travel
# 4   569-71-4390      B   Mandalay        Normal    Male                 NaN
# ..          ...    ...        ...           ...     ...                 ...
# 95  257-73-1380      C  Naypyitaw           NaN    Male                 NaN
# 96  787-87-2010      A     Yangon        Member    Male   Health and beauty
# 97  504-35-8843      A     Yangon        Normal    Male   Sports and travel
# 98  199-75-8169      A     Yangon        Member    Male   Sports and travel
# 99  222-42-0244      B   Mandalay           NaN     NaN                 NaN
#
#     Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0        83.17       6.0  24.9510  523.9710  3/20/2019  11:23         Cash
# 1          NaN      10.0  29.3800  616.9800  1/29/2019  14:26      Ewallet
# 2        55.61       7.0  19.4635  408.7335  3/23/2019  12:41         Cash
# 3          NaN       3.0   6.4455  135.3555   2/3/2019  11:46          NaN
# 4          NaN       2.0   2.1870   45.9270  1/25/2019  14:29      Ewallet
# ..         ...       ...      ...       ...        ...    ...          ...
# 95       82.93       NaN  16.5860  348.3060  1/20/2019  16:51          NaN
# 96       55.50       NaN  11.1000  233.1000  1/20/2019  15:48  Credit card
# 97       42.47       NaN   2.1235   44.5935   1/2/2019  16:57          NaN
# 98       15.81       NaN   7.9050  166.0050   3/6/2019  12:27  Credit card
# 99       72.11       9.0  32.4495  681.4395  1/28/2019  13:53  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# 0   499.02                 4.761905       24.9510     7.3
# 1   587.60                 4.761905       29.3800     9.0
# 2   389.27                 4.761905       19.4635     8.5
# 3   128.91                 4.761905        6.4455     9.3
# 4    43.74                 4.761905        2.1870     6.9
# ..     ...                      ...           ...     ...
# 95  331.72                 4.761905       16.5860     9.6
# 96  222.00                 4.761905       11.1000     6.6
# 97   42.47                 4.761905        2.1235     5.7
# 98  158.10                 4.761905        7.9050     8.6
# 99  648.99                 4.761905       32.4495     7.7
#
# [100 rows x 17 columns]

# %%
impute = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
impute.fit(df)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
imputed_arr = impute.transform(df)

# %% [markdown]
# Show and explain the documentation for simple imputer
#
#
# *   fit()
# *   fit_transform()
# * transform()
#
#
#
# https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html#sklearn.impute.SimpleImputer

# %%
imputed_df = pd.DataFrame(imputed_arr, columns=df.columns)

# %%
imputed_df
# Out:
#      Invoice ID Branch       City Customer type  Gender        Product line  \
# 0   451-28-5717      C  Naypyitaw        Normal    Male  Home and lifestyle
# 1   137-63-5492      C  Naypyitaw        Normal    Male  Home and lifestyle
# 2   733-29-1227      C  Naypyitaw        Normal    Male  Home and lifestyle
# 3   322-02-2271      B   Mandalay        Normal  Female   Sports and travel
# 4   569-71-4390      B   Mandalay        Normal    Male  Home and lifestyle
# ..          ...    ...        ...           ...     ...                 ...
# 95  257-73-1380      C  Naypyitaw        Normal    Male  Home and lifestyle
# 96  787-87-2010      A     Yangon        Member    Male   Health and beauty
# 97  504-35-8843      A     Yangon        Normal    Male   Sports and travel
# 98  199-75-8169      A     Yangon        Member    Male   Sports and travel
# 99  222-42-0244      B   Mandalay        Normal    Male  Home and lifestyle
#
#    Unit price Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       83.17      6.0   24.951   523.971  3/20/2019  11:23         Cash
# 1       10.99     10.0    29.38    616.98  1/29/2019  14:26      Ewallet
# 2       55.61      7.0  19.4635  408.7335  3/23/2019  12:41         Cash
# 3       10.99      3.0   6.4455  135.3555   2/3/2019  11:46      Ewallet
# 4       10.99      2.0    2.187    45.927  1/25/2019  14:29      Ewallet
# ..        ...      ...      ...       ...        ...    ...          ...
# 95      82.93      6.0   16.586   348.306  1/20/2019  16:51      Ewallet
# 96       55.5      6.0     11.1     233.1  1/20/2019  15:48  Credit card
# 97      42.47      6.0   2.1235   44.5935   1/2/2019  16:57      Ewallet
# 98      15.81      6.0    7.905   166.005   3/6/2019  12:27  Credit card
# 99      72.11      9.0  32.4495  681.4395  1/28/2019  13:53  Credit card
#
#       cogs gross margin percentage gross income Rating
# 0   499.02                4.761905       24.951    7.3
# 1    587.6                4.761905        29.38    9.0
# 2   389.27                4.761905      19.4635    8.5
# 3   128.91                4.761905       6.4455    9.3
# 4    43.74                4.761905        2.187    6.9
# ..     ...                     ...          ...    ...
# 95  331.72                4.761905       16.586    9.6
# 96   222.0                4.761905         11.1    6.6
# 97   42.47                4.761905       2.1235    5.7
# 98   158.1                4.761905        7.905    8.6
# 99  648.99                4.761905      32.4495    7.7
#
# [100 rows x 17 columns]

# %%
numerical_features = df.select_dtypes(include=[np.number])
categorical_features = df.select_dtypes(exclude=[np.number])

print('Features not included in either numerical_features or categorical_features:')
set(df.columns).symmetric_difference(set(numerical_features.columns).union(set(categorical_features.columns)))
# Out:
# Features not included in either numerical_features or categorical_features:
# set()

# %% [markdown]
# ### Imputation in one go

# %%
numerical_imputer = SimpleImputer(strategy="median")
categorical_imputer = SimpleImputer(strategy="most_frequent")

numerical_imputed_arr = numerical_imputer.fit_transform(numerical_features)
categorical_imputed_arr = categorical_imputer.fit_transform(categorical_features)

numerical_imputed_df = pd.DataFrame(numerical_imputed_arr, columns=numerical_features.columns)
categorical_imputed_df = pd.DataFrame(categorical_imputed_arr, columns=categorical_features.columns)

imputed_df = pd.merge(numerical_imputed_df, categorical_imputed_df, left_index=True, right_index=True)

# %%
imputed_df.describe()
# Out:
#        Unit price   Quantity      Tax 5%       Total        cogs  \
# count  100.000000  100.00000  100.000000  100.000000  100.000000
# mean    53.846600    5.83000   15.550900  326.568900  311.018000
# std     23.285683    2.38283   11.515250  241.820249  230.304999
# min     10.990000    1.00000    1.476000   30.996000   29.520000
# 25%     40.710000    4.75000    6.093750  127.968750  121.875000
# 50%     52.890000    6.00000   11.907750  250.062750  238.155000
# 75%     64.125000    7.00000   21.790375  457.597875  435.807500
# max     99.730000   10.00000   44.878500  942.448500  897.570000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+02    100.000000  100.000000
# mean              4.761905e+00     15.550900    6.810000
# std               1.249714e-14     11.515250    1.849352
# min               4.761905e+00      1.476000    4.000000
# 25%               4.761905e+00      6.093750    5.000000
# 50%               4.761905e+00     11.907750    6.700000
# 75%               4.761905e+00     21.790375    8.500000
# max               4.761905e+00     44.878500    9.900000

# %%
# %%script echo skipping
# !pip install -q ydata_profiling
# from ydata_profiling import ProfileReport
# profile = ProfileReport(imputed_df, title="Profiling Report")
# profile
# Out:
# skipping

# %% [markdown]
# ## Encoding categorical features
#
# What is N.O.I.R?
#
# https://scikit-learn.org/stable/api/sklearn.preprocessing.html

# %%
df = imputed_df.copy(deep=True)
numerical_features = df.select_dtypes(include=[np.number])
categorical_features = df.select_dtypes(exclude=[np.number])

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
product_line_df = df[['Product line']]

# %%
enc = OrdinalEncoder(dtype=int)
product_line_encoded_arr = enc.fit_transform(product_line_df)

# %%
ic(enc.categories_)
ic(enc.n_features_in_)
ic(enc.feature_names_in_)
# Out:
# enc.categories_: [array(['Electronic accessories', 'Fashion accessories',
#                         'Food and beverages', 'Health and beauty', 'Home and lifestyle',
#                         'Sports and travel'], dtype=object)]
# enc.n_features_in_: 1
# enc.feature_names_in_: array(['Product line'], dtype=object)
# array(['Product line'], dtype=object)

# %%
product_line_encoded_df = pd.DataFrame(product_line_encoded_arr, columns=product_line_df.columns)

# %%
product_line_encoded_df[['decoded Product line']] = enc.inverse_transform(product_line_encoded_arr)

# %%
product_line_encoded_df.head()
# Out:
#    Product line decoded Product line
# 0             4   Home and lifestyle
# 1             4   Home and lifestyle
# 2             4   Home and lifestyle
# 3             5    Sports and travel
# 4             4   Home and lifestyle

# %%
product_line_df.head()
# Out:
#          Product line
# 0  Home and lifestyle
# 1  Home and lifestyle
# 2  Home and lifestyle
# 3   Sports and travel
# 4  Home and lifestyle

# %% [markdown]
# Unnecessary order required?

# %%
# Enter OneHotEncoder

# %% [markdown]
# ### Transforming floating point features
# https://scikit-learn.org/stable/api/sklearn.preprocessing.html

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = scaler.fit_transform(numerical_features)
scaled_df = pd.DataFrame(scaled_features, columns=numerical_features.columns)

scaled_numerical_full_df = pd.merge(numerical_features, scaled_df, suffixes=['_org', '_tr'], right_index=True, left_index=True)

# %%
scaled_numerical_full_df.columns = sorted(scaled_numerical_full_df.columns)

# %%
scaled_numerical_full_df
# Out:
#     Quantity_org  Quantity_tr  Rating_org  Rating_tr  Tax 5%_org  Tax 5%_tr  \
# 0          83.17          6.0     24.9510   523.9710      499.02   4.761905
# 1          52.89         10.0     29.3800   616.9800      587.60   4.761905
# 2          55.61          7.0     19.4635   408.7335      389.27   4.761905
# 3          52.89          3.0      6.4455   135.3555      128.91   4.761905
# 4          52.89          2.0      2.1870    45.9270       43.74   4.761905
# ..           ...          ...         ...        ...         ...        ...
# 95         82.93          6.0     16.5860   348.3060      331.72   4.761905
# 96         55.50          6.0     11.1000   233.1000      222.00   4.761905
# 97         42.47          6.0      2.1235    44.5935       42.47   4.761905
# 98         15.81          6.0      7.9050   166.0050      158.10   4.761905
# 99         72.11          9.0     32.4495   681.4395      648.99   4.761905
#
#     Total_org  Total_tr  Unit price_org  Unit price_tr  cogs_org   cogs_tr  \
# 0     24.9510       7.3        1.265633       0.071703  0.820430  0.820430
# 1     29.3800       9.0       -0.041288       1.758836  1.206988  1.206988
# 2     19.4635       8.5        0.076110       0.493486  0.341487  0.341487
# 3      6.4455       9.3       -0.041288      -1.193647 -0.794709 -0.794709
# 4      2.1870       6.9       -0.041288      -1.615430 -1.166386 -1.166386
# ..        ...       ...             ...            ...       ...       ...
# 95    16.5860       9.6        1.255274       0.071703  0.090342  0.090342
# 96    11.1000       6.6        0.071363       0.071703 -0.388469 -0.388469
# 97     2.1235       5.7       -0.491028       0.071703 -1.171928 -1.171928
# 98     7.9050       8.6       -1.641705       0.071703 -0.667325 -0.667325
# 99    32.4495       7.7        0.788270       1.337053  1.474890  1.474890
#
#     gross income_org  gross income_tr  gross margin percentage_org  \
# 0           0.820430     8.881784e-16                     0.820430
# 1           1.206988     8.881784e-16                     1.206988
# 2           0.341487     8.881784e-16                     0.341487
# 3          -0.794709     8.881784e-16                    -0.794709
# 4          -1.166386     8.881784e-16                    -1.166386
# ..               ...              ...                          ...
# 95          0.090342     8.881784e-16                     0.090342
# 96         -0.388469     8.881784e-16                    -0.388469
# 97         -1.171928     8.881784e-16                    -1.171928
# 98         -0.667325     8.881784e-16                    -0.667325
# 99          1.474890     8.881784e-16                     1.474890
#
#     gross margin percentage_tr
# 0                     0.266293
# 1                     1.190165
# 2                     0.918438
# 3                     1.353201
# 4                     0.048911
# ..                         ...
# 95                    1.516237
# 96                   -0.114125
# 97                   -0.603234
# 98                    0.972783
# 99                    0.483674
#
# [100 rows x 16 columns]
