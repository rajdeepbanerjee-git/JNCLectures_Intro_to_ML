# %% [markdown]
# Classifier Comparison![sphx_glr_plot_classifier_comparison_001.png](data:image/png;base64,...)

# %% [markdown]
# Tasks:
#
# 1.   Reproduce the contour plots in the first column using your own k-NN classification algorithm using the supplied synthetic data. Also apply this k-NN to Iris data supplied by sklearn
# 2.   Use linear regression for Iris Data supplied by sklearn and the three synthetic data
#
#
# *   Data and contour plots for the synthetic data: [Sklearn Classifier Comparison](https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html)
# *   Iris Dataset: [The Iris Dataset Page](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html)
