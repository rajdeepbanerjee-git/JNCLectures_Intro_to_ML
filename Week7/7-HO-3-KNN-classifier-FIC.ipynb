# %% [markdown]
# # Build KNN Classifier Pipeline

# %% [markdown]
# ## Import the required components from sklearn

# %%
from sklearn.pipeline import ?
from sklearn.? import StandardScaler
from ? import KNeighborsClassifier

# %% [markdown]
# ## Build the pipeline which is exactly like the following:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
knn_classifier_pipeline = ?

knn_classifier_pipeline
# Out:
# Pipeline(steps=[('feature_scaling', StandardScaler()),
#                 ('classifier', KNeighborsClassifier())])

# %% [markdown]
# # Load Breast Cancer Data

# %%
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer(as_frame=True)

# %%
X, y = data['data'].to_numpy(), data['target'].to_numpy()

# %% [markdown]
# ## Split Data into train and test

# %%
from ? import train_test_split

# %% [markdown]
# Split the data into train and test. With test fraction as 0.25. Use the random seed as 42

# %%
X_train, X_test, y_train, y_test = ?(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((426, 30), (143, 30), (426,), (143,))

# %% [markdown]
# # Model selection using grid search cross-validation

# %% [markdown]
# ## Load required sklearn components

# %%
from sklearn.metrics import ?, ?, ?

# %%
from sklearn.model_selection import ?

# %%
score = make_scorer(accuracy_score)

# %% [markdown]
# Choose the number of neighbors in KNN to be between 1 and 20 for the cross validation

# %%
parameters = ?

# %% [markdown]
# ## Build grid search cross-validator as follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Build the grid search cross validation

# %%
gscv = ?

# %%
gscv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('feature_scaling', StandardScaler()),
#                                        ('classifier', KNeighborsClassifier())]),
#              param_grid={'classifier__n_neighbors': range(1, 20)},
#              return_train_score=True, scoring=make_scorer(accuracy_score))

# %% [markdown]
# Choose the optimal model from cross validation

# %%
final_knn_classifier = ?

# %% [markdown]
# Make predictions for the test data

# %%
yhat = final_knn_classifier.predict(X_test)

# %% [markdown]
# Get accuracy for the test data

# %%
?(y_test, yhat)
# Out:
# 0.965034965034965

# %% [markdown]
# Since the classifier is built to aid diagnosis, let's see how good it's recall is...

# %%
?(y_test, yhat)
# Out:
# 0.9662921348314607
