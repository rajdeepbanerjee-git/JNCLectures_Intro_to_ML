# %% [markdown]
# # Introduction to Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Declaring a Series and Dataframe

# %%
data = {
    'date': ['21-07-2015', '02-08-2012', '01-12-2016', '05-07-2015', '06-04-2018'],
    'code': [123, 3211, 1, 567, 98],
    'item': ['milk', 'carrots', 'soap', 'pen', 'onion'],
    'price': [25.55, 16.2, 52.0, 5, 11],
    'broadCategory': ['dairy', 'vegetable', 'consumable', 'consumable', 'vegetable'],
    'inflation': [10., 22., 5., 0., 100.],
    'demand': [1.0, None, None, 0.3, 0.6]
}

indices = [0, 88, 1, 55, 2] # are immutable

serie = pd.Series(data['date'], index = indices, name='date')
df = pd.DataFrame(data, index = indices)

# %%
inflation_dict_list = [
    {'broadCategory': 'dairy', 'inflation': 10.},
    {'broadCategory': 'vegetable', 'inflation': 30.},
    {'broadCategory': 'consumable', 'inflation': 5.},
    {'broadCategory': 'meat', 'inflation': 125.},
    {'broadCategory': 'non-essentials', 'inflation': 85.},
    {'broadCategory': 'luxury', 'inflation': 250.}
]
inflation_df = pd.DataFrame(inflation_dict_list)

# %% [markdown]
# ## Alternate ways of loading a dataframe

# %% [markdown]
# Download from internet

# %%
# This is how you execute a `shell` command in a jupyter cell
# get data

# !wget https://raw.githubusercontent.com/amankharwal/Website-data/master/Groceries_dataset.csv

# %% [markdown]
# Reading from a CSV file

# %%
# read a csv file from the disk
# df = pd.read_csv("/content/Groceries_dataset.csv")

# %% [markdown]
# 1.   Find out how to open an excel file.
# 2.   Find out how to save a dataframe as an excel/csv file
# 3. Dataframe as a collection of Pandas Series
# 4. Refer to pg. 120 for all possible methods

# %% [markdown]
# ## On Dataframes and Series

# %%
serie
# Out:
# 0     21-07-2015
# 88    02-08-2012
# 1     01-12-2016
# 55    05-07-2015
# 2     06-04-2018
# Name: date, dtype: object

# %%
type(serie)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#           date  code     item  price broadCategory  inflation  demand
# 0   21-07-2015   123     milk  25.55         dairy       10.0     1.0
# 88  02-08-2012  3211  carrots  16.20     vegetable       22.0     NaN
# 1   01-12-2016     1     soap  52.00    consumable        5.0     NaN
# 55  05-07-2015   567      pen   5.00    consumable        0.0     0.3
# 2   06-04-2018    98    onion  11.00     vegetable      100.0     0.6

# %%
inflation_df
# Out:
#     broadCategory  inflation
# 0           dairy       10.0
# 1       vegetable       30.0
# 2      consumable        5.0
# 3            meat      125.0
# 4  non-essentials       85.0
# 5          luxury      250.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['date']
# Out:
# 0     21-07-2015
# 88    02-08-2012
# 1     01-12-2016
# 55    05-07-2015
# 2     06-04-2018
# Name: date, dtype: object

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Getting index, values and the name of a series object

# %%
df['date'].index, df['date'].values, df['date'].name
# Out:
# (Int64Index([0, 88, 1, 55, 2], dtype='int64'),
#  array(['21-07-2015', '02-08-2012', '01-12-2016', '05-07-2015',
#         '06-04-2018'], dtype=object),
#  'date')

# %% [markdown]
# Printing selected columns of a dataframe

# %%
df[['date', 'broadCategory']]
# Out:
#           date broadCategory
# 0   21-07-2015         dairy
# 88  02-08-2012     vegetable
# 1   01-12-2016    consumable
# 55  05-07-2015    consumable
# 2   06-04-2018     vegetable

# %%
len(df)
# Out:
# 5

# %%
# shape is an attribute
df.shape
# Out:
# (5, 7)

# %%
# elaborate on random seed
df.sample(3, random_state=123456789)
# Out:
#           date  code     item  price broadCategory  inflation  demand
# 55  05-07-2015   567      pen    5.0    consumable        0.0     0.3
# 88  02-08-2012  3211  carrots   16.2     vegetable       22.0     NaN
# 1   01-12-2016     1     soap   52.0    consumable        5.0     NaN

# %%
df.head(10)
# Out:
#           date  code     item  price broadCategory  inflation  demand
# 0   21-07-2015   123     milk  25.55         dairy       10.0     1.0
# 88  02-08-2012  3211  carrots  16.20     vegetable       22.0     NaN
# 1   01-12-2016     1     soap  52.00    consumable        5.0     NaN
# 55  05-07-2015   567      pen   5.00    consumable        0.0     0.3
# 2   06-04-2018    98    onion  11.00     vegetable      100.0     0.6

# %%
df.tail(5)
# Out:
#           date  code     item  price broadCategory  inflation  demand
# 0   21-07-2015   123     milk  25.55         dairy       10.0     1.0
# 88  02-08-2012  3211  carrots  16.20     vegetable       22.0     NaN
# 1   01-12-2016     1     soap  52.00    consumable        5.0     NaN
# 55  05-07-2015   567      pen   5.00    consumable        0.0     0.3
# 2   06-04-2018    98    onion  11.00     vegetable      100.0     0.6

# %%
# atrributes. How is it different from methods
df.index, df.columns, df.shape
# Out:
# (Int64Index([0, 88, 1, 55, 2], dtype='int64'),
#  Index(['date', 'code', 'item', 'price', 'broadCategory', 'inflation',
#         'demand'],
#        dtype='object'),
#  (5, 7))

# %%
df.dtypes
# Out:
# date              object
# code               int64
# item              object
# price            float64
# broadCategory     object
# inflation        float64
# demand           float64
# dtype: object

# %% [markdown]
# Change dtypes

# %%
df = df.astype({'date': 'datetime64[ns]', 'broadCategory': 'category'})
# Out:
# <ipython-input-23-c5fc547f20ee>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = df.astype({'date': 'datetime64[ns]', 'broadCategory': 'category'})

# %%
# An alternate way to change to datetime
# df['Date'] = pd.to_datetime(df['Date'], yearfirst=True)

# %%
df.sort_values(['date']) #, ascending=False)
# Out:
#          date  code     item  price broadCategory  inflation  demand
# 88 2012-02-08  3211  carrots  16.20     vegetable       22.0     NaN
# 55 2015-05-07   567      pen   5.00    consumable        0.0     0.3
# 0  2015-07-21   123     milk  25.55         dairy       10.0     1.0
# 1  2016-01-12     1     soap  52.00    consumable        5.0     NaN
# 2  2018-06-04    98    onion  11.00     vegetable      100.0     0.6

# %% [markdown]
# *What happens if 'date' is an object type instead of datetime? *

# %%
df['broadCategory'].unique(), df['broadCategory'].nunique()
# Out:
# (['dairy', 'vegetable', 'consumable']
#  Categories (3, object): ['consumable', 'dairy', 'vegetable'],
#  3)

# %% [markdown]
# ### Indexing, selection, and filtering
# Obtaining records through indexing: loc and iloc

# %%
df.iloc[1]
# Out:
# date             2012-02-08 00:00:00
# code                            3211
# item                         carrots
# price                           16.2
# broadCategory              vegetable
# inflation                       22.0
# demand                           NaN
# Name: 88, dtype: object

# %%
df.loc[88]
# Out:
# date             2012-02-08 00:00:00
# code                            3211
# item                         carrots
# price                           16.2
# broadCategory              vegetable
# inflation                       22.0
# demand                           NaN
# Name: 88, dtype: object

# %% [markdown]
# Condition-based selection

# %%
df[df['price'] < 20.]

# explicit notation
# df.loc[df['price'] < 20., :]
# Out:
#          date  code     item  price broadCategory  inflation  demand
# 88 2012-02-08  3211  carrots   16.2     vegetable       22.0     NaN
# 55 2015-05-07   567      pen    5.0    consumable        0.0     0.3
# 2  2018-06-04    98    onion   11.0     vegetable      100.0     0.6

# %% [markdown]
# How to print only 'date', and 'code' for the same condition?

# %% [markdown]
# Read about other indexing methods on page. 128.

# %% [markdown]
# Making selections based on missing values:
# 1. isnull()
# 2. notnull()
# 3. dropna()
#
# Try to understand all the arguments for the above three methods.

# %% [markdown]
# ### Manipulating records/columns

# %%
df.dropna() #(inplace=True)
# Out:
#          date  code   item  price broadCategory  inflation  demand
# 0  2015-07-21   123   milk  25.55         dairy       10.0     1.0
# 55 2015-05-07   567    pen   5.00    consumable        0.0     0.3
# 2  2018-06-04    98  onion  11.00     vegetable      100.0     0.6

# %% [markdown]
# Check the effect of inplace=True

# %% [markdown]
# ### The *apply* function

# %%
def convert_percentage_into_fraction(pc):
  return pc / 100.

# %%
df['inflationFraction'] = df['inflation'].apply(convert_percentage_into_fraction)

# %%
df
# Out:
#          date  code     item  price broadCategory  inflation  demand  \
# 0  2015-07-21   123     milk  25.55         dairy       10.0     1.0
# 88 2012-02-08  3211  carrots  16.20     vegetable       22.0     NaN
# 1  2016-01-12     1     soap  52.00    consumable        5.0     NaN
# 55 2015-05-07   567      pen   5.00    consumable        0.0     0.3
# 2  2018-06-04    98    onion  11.00     vegetable      100.0     0.6
#
#     inflationFraction
# 0                0.10
# 88               0.22
# 1                0.05
# 55               0.00
# 2                1.00

# %% [markdown]
# Try and understand the following methods. Optionally use the arguments provided
#
#
# 1. sort_index()
# 2. sort_values(); ascending,
# 3. drop_duplicates()
# 4. reindex()
# 5. drop(). Use axis=0, axis=1 arguments
# 6. rank(); ascending, na_option, pct...
#
# Also, use 'inplace=True' where ever allowed and understand its effect

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# Simplest way to handle missing values: Drop them!

# %%
df
# Out:
#          date  code     item  price broadCategory  inflation  demand  \
# 0  2015-07-21   123     milk  25.55         dairy       10.0     1.0
# 88 2012-02-08  3211  carrots  16.20     vegetable       22.0     NaN
# 1  2016-01-12     1     soap  52.00    consumable        5.0     NaN
# 55 2015-05-07   567      pen   5.00    consumable        0.0     0.3
# 2  2018-06-04    98    onion  11.00     vegetable      100.0     0.6
#
#     inflationFraction
# 0                0.10
# 88               0.22
# 1                0.05
# 55               0.00
# 2                1.00

# %%
df.dropna()
# Out:
#          date  code   item  price broadCategory  inflation  demand  \
# 0  2015-07-21   123   milk  25.55         dairy       10.0     1.0
# 55 2015-05-07   567    pen   5.00    consumable        0.0     0.3
# 2  2018-06-04    98  onion  11.00     vegetable      100.0     0.6
#
#     inflationFraction
# 0                 0.1
# 55                0.0
# 2                 1.0

# %%
missing_val_serie = pd.Series([1., 2., 1., None, None, None, None, 2., 3.0, None, None, 2., None])

# %%
missing_val_serie.fillna(value=0)
# Out:
# 0     1.0
# 1     2.0
# 2     1.0
# 3     0.0
# 4     0.0
# 5     0.0
# 6     0.0
# 7     2.0
# 8     3.0
# 9     0.0
# 10    0.0
# 11    2.0
# 12    0.0
# dtype: float64

# %%
missing_val_serie.fillna(method='ffill', limit=2) # try bfill
# Out:
# 0     1.0
# 1     2.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     NaN
# 6     NaN
# 7     2.0
# 8     3.0
# 9     3.0
# 10    3.0
# 11    2.0
# 12    2.0
# dtype: float64

# %% [markdown]
# What does the following command do?

# %%
missing_val_serie.fillna(value=missing_val_serie.mean()) # try bfill
# Out:
# 0     1.000000
# 1     2.000000
# 2     1.000000
# 3     1.833333
# 4     1.833333
# 5     1.833333
# 6     1.833333
# 7     2.000000
# 8     3.000000
# 9     1.833333
# 10    1.833333
# 11    2.000000
# 12    1.833333
# dtype: float64

# %% [markdown]
# Arguments to try: inplace, limit, etc.

# %%
missing_val_serie.interpolate()
# Out:
# 0     1.000000
# 1     2.000000
# 2     1.000000
# 3     1.200000
# 4     1.400000
# 5     1.600000
# 6     1.800000
# 7     2.000000
# 8     3.000000
# 9     2.666667
# 10    2.333333
# 11    2.000000
# 12    2.000000
# dtype: float64

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# describe

# %% [markdown]
# cumsum

# %%
df['price'].cumsum()
# Out:
# 0        25.55
# 88       41.75
# 1        93.75
# 55       98.75
# 2       109.75
# 2099    140.30
# 2100    160.30
# 2101    162.30
# 2102    163.30
# 2103    188.30
# Name: price, dtype: float64

# %%
df['broadCategory'].value_counts()
# Out:
# consumable    4
# vegetable     4
# dairy         2
# Name: broadCategory, dtype: int64

# %% [markdown]
# Try out:
#
#
# 1.   sum
# 2.   min
# 3. max
# 4. idxmin
# 5. idxmax
# 6. unique
# 7. nunique

# %% [markdown]
# Page 139 for descriptive and summary statistics

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Transpose

# %%
df
# Out:
#            date  code     item  price broadCategory  inflation  demand  \
# 0    2015-07-21   123     milk  25.55         dairy       10.0     1.0
# 88   2012-02-08  3211  carrots  16.20     vegetable       22.0     NaN
# 1    2016-01-12     1     soap  52.00    consumable        5.0     NaN
# 55   2015-05-07   567      pen   5.00    consumable        0.0     0.3
# 2    2018-06-04    98    onion  11.00     vegetable      100.0     0.6
# 2099 2022-07-21   324     curd  30.55         dairy       10.0     1.0
# 2100 2023-02-08   543    beans  20.00     vegetable       22.0     NaN
# 2101 2023-01-12   654  shampoo   2.00    consumable        5.0     NaN
# 2102 2023-05-05    76   pencil   1.00    consumable        0.0     NaN
# 2103 2020-06-04   235   garlic  25.00     vegetable      100.0     0.6
#
#       inflationFraction
# 0                  0.10
# 88                 0.22
# 1                  0.05
# 55                 0.00
# 2                  1.00
# 2099                NaN
# 2100                NaN
# 2101                NaN
# 2102                NaN
# 2103                NaN

# %%
df.T
# Out:
#                                   0                    88    \
# date               2015-07-21 00:00:00  2012-02-08 00:00:00
# code                               123                 3211
# item                              milk              carrots
# price                            25.55                 16.2
# broadCategory                    dairy            vegetable
# inflation                         10.0                 22.0
# demand                             1.0                  NaN
# inflationFraction                  0.1                 0.22
#
#                                   1                    55    \
# date               2016-01-12 00:00:00  2015-05-07 00:00:00
# code                                 1                  567
# item                              soap                  pen
# price                             52.0                  5.0
# broadCategory               consumable           consumable
# inflation                          5.0                  0.0
# demand                             NaN                  0.3
# inflationFraction                 0.05                  0.0
#
#                                   2                    2099  \
# date               2018-06-04 00:00:00  2022-07-21 00:00:00
# code                                98                  324
# item                             onion                 curd
# price                             11.0                30.55
# broadCategory                vegetable                dairy
# inflation                        100.0                 10.0
# demand                             0.6                  1.0
# inflationFraction                  1.0                  NaN
#
#                                   2100                 2101  \
# date               2023-02-08 00:00:00  2023-01-12 00:00:00
# code                               543                  654
# item                             beans              shampoo
# price                             20.0                  2.0
# broadCategory                vegetable           consumable
# inflation                         22.0                  5.0
# demand                             NaN                  NaN
# inflationFraction                  NaN                  NaN
#
#                                   2102                 2103
# date               2023-05-05 00:00:00  2020-06-04 00:00:00
# code                                76                  235
# item                            pencil               garlic
# price                              1.0                 25.0
# broadCategory               consumable            vegetable
# inflation                          0.0                100.0
# demand                             NaN                  0.6
# inflationFraction                  NaN                  NaN

# %% [markdown]
# Concatenation

# %%
data = {
    'date': ['21-07-2022', '02-08-2023', '01-12-2023', '05-05-2023', '06-04-2020'],
    'code': [324, 543, 654, 76, 235],
    'item': ['curd', 'beans', 'shampoo', 'pencil', 'garlic'],
    'price': [30.55, 20., 2.0, 1, 25],
    'broadCategory': ['dairy', 'vegetable', 'consumable', 'consumable', 'vegetable'],
    'inflation': [10., 22., 5., 0., 100.],
    'demand': [1.0, None, None, None, 0.6]
}

indices = [2099, 2100, 2101, 2102, 2103] # are immutable

new_df = pd.DataFrame(data, index = indices)

new_df = new_df.astype({'date': 'datetime64[ns]', 'broadCategory': 'category'})
# Out:
# <ipython-input-43-09d8bb51c868>:15: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   new_df = new_df.astype({'date': 'datetime64[ns]', 'broadCategory': 'category'})

# %%
df = pd.concat([df, new_df])

# %% [markdown]
# page 181 for all options

# %% [markdown]
# Merging / Joins
#
#
# *   how = left, right, inner, outer, etc
# *   check all the arguments on https://pandas.pydata.org/docs/reference/api/pandas.merge.html

# %%
df
# Out:
#            date  code     item  price broadCategory  inflation  demand  \
# 0    2015-07-21   123     milk  25.55         dairy       10.0     1.0
# 88   2012-02-08  3211  carrots  16.20     vegetable       22.0     NaN
# 1    2016-01-12     1     soap  52.00    consumable        5.0     NaN
# 55   2015-05-07   567      pen   5.00    consumable        0.0     0.3
# 2    2018-06-04    98    onion  11.00     vegetable      100.0     0.6
# 2099 2022-07-21   324     curd  30.55         dairy       10.0     1.0
# 2100 2023-02-08   543    beans  20.00     vegetable       22.0     NaN
# 2101 2023-01-12   654  shampoo   2.00    consumable        5.0     NaN
# 2102 2023-05-05    76   pencil   1.00    consumable        0.0     NaN
# 2103 2020-06-04   235   garlic  25.00     vegetable      100.0     0.6
#
#       inflationFraction
# 0                  0.10
# 88                 0.22
# 1                  0.05
# 55                 0.00
# 2                  1.00
# 2099                NaN
# 2100                NaN
# 2101                NaN
# 2102                NaN
# 2103                NaN

# %%
inflation_df
# Out:
#     broadCategory  inflation
# 0           dairy       10.0
# 1       vegetable       30.0
# 2      consumable        5.0
# 3            meat      125.0
# 4  non-essentials       85.0
# 5          luxury      250.0

# %%
pd.merge(df, inflation_df, how='inner', left_on = 'broadCategory', right_on = 'broadCategory', suffixes=['_old', '_updated'])
# Out:
#         date  code     item  price broadCategory  inflation_old  demand  \
# 0 2015-07-21   123     milk  25.55         dairy           10.0     1.0
# 1 2022-07-21   324     curd  30.55         dairy           10.0     1.0
# 2 2012-02-08  3211  carrots  16.20     vegetable           22.0     NaN
# 3 2018-06-04    98    onion  11.00     vegetable          100.0     0.6
# 4 2023-02-08   543    beans  20.00     vegetable           22.0     NaN
# 5 2020-06-04   235   garlic  25.00     vegetable          100.0     0.6
# 6 2016-01-12     1     soap  52.00    consumable            5.0     NaN
# 7 2015-05-07   567      pen   5.00    consumable            0.0     0.3
# 8 2023-01-12   654  shampoo   2.00    consumable            5.0     NaN
# 9 2023-05-05    76   pencil   1.00    consumable            0.0     NaN
#
#    inflationFraction  inflation_updated
# 0               0.10               10.0
# 1                NaN               10.0
# 2               0.22               30.0
# 3               1.00               30.0
# 4                NaN               30.0
# 5                NaN               30.0
# 6               0.05                5.0
# 7               0.00                5.0
# 8                NaN                5.0
# 9                NaN                5.0

# %% [markdown]
# Pivoting

# %%
df
# Out:
#            date  code     item  price broadCategory  inflation  demand  \
# 0    2015-07-21   123     milk  25.55         dairy       10.0     1.0
# 88   2012-02-08  3211  carrots  16.20     vegetable       22.0     NaN
# 1    2016-01-12     1     soap  52.00    consumable        5.0     NaN
# 55   2015-05-07   567      pen   5.00    consumable        0.0     0.3
# 2    2018-06-04    98    onion  11.00     vegetable      100.0     0.6
# 2099 2022-07-21   324     curd  30.55         dairy       10.0     1.0
# 2100 2023-02-08   543    beans  20.00     vegetable       22.0     NaN
# 2101 2023-01-12   654  shampoo   2.00    consumable        5.0     NaN
# 2102 2023-05-05    76   pencil   1.00    consumable        0.0     NaN
# 2103 2020-06-04   235   garlic  25.00     vegetable      100.0     0.6
#
#       inflationFraction
# 0                  0.10
# 88                 0.22
# 1                  0.05
# 55                 0.00
# 2                  1.00
# 2099                NaN
# 2100                NaN
# 2101                NaN
# 2102                NaN
# 2103                NaN

# %%
pd.pivot_table(df, values='item', index='broadCategory', aggfunc=list)
# Out:
#                                           item
# broadCategory
# consumable        [soap, pen, shampoo, pencil]
# dairy                             [milk, curd]
# vegetable      [carrots, onion, beans, garlic]

# %%
pd.pivot_table(df, values='inflation', index='broadCategory', aggfunc=['mean', list, 'max', 'min'])
# Out:
#                    mean                        list       max       min
#               inflation                   inflation inflation inflation
# broadCategory
# consumable          2.5        [5.0, 0.0, 5.0, 0.0]       5.0       0.0
# dairy              10.0                [10.0, 10.0]      10.0      10.0
# vegetable          61.0  [22.0, 100.0, 22.0, 100.0]     100.0      22.0

# %% [markdown]
# groupby

# %%
df.groupby(['broadCategory']).mean()
# Out:
# <ipython-input-73-e39b5e5e6f79>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['broadCategory']).mean()
#                   code  price  inflation  demand  inflationFraction
# broadCategory
# consumable      324.50  15.00        2.5     0.3              0.025
# dairy           223.50  28.05       10.0     1.0              0.100
# vegetable      1021.75  18.05       61.0     0.6              0.610

# %%
df.groupby(['broadCategory']).max()
# Out:
#                     date  code   item  price  inflation  demand  \
# broadCategory
# consumable    2023-05-05   654   soap  52.00        5.0     0.3
# dairy         2022-07-21   324   milk  30.55       10.0     1.0
# vegetable     2023-02-08  3211  onion  25.00      100.0     0.6
#
#                inflationFraction
# broadCategory
# consumable                  0.05
# dairy                       0.10
# vegetable                   1.00
